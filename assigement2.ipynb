# %%
Q1. How do you comment code in Python? What are the different types of comments?

Ans : 
     comment code in python are identify with has symbol, # , and extend to thr end of the line 
    
     There are two type of comment line (code)
        (1) single line comment
        (2) multi line comment
        
-------------------------------------------------------------------------------------------------------------------------------------------------------

Q2. What are variables in Python? How do you declare and assign values to variables?

Ans :
    vairables in python is a symbolic name that is a reference or pointer to an object
    
    and The assignment operator, denoted by the “=” symbol, is the operator that is used to assign values to variables in Python
    
-------------------------------------------------------------------------------------------------------------------------------------------------------

Q3. How do you convert one data type to another in Python?

Ans :
    I can convert one data type to another in Python using type conversion functions such as int(), float(), str(), and bool(). 
    For example :-  to convert a string to an integer, you would use the int() function like this : int("10").
    
-------------------------------------------------------------------------------------------------------------------------------------------------------

Q4. How do you write and execute a Python script from the command line?

Ans :
    steps:

    1. Open a text editor and write a Python code.
    2. Save the file with a .py extension. 
    3. Open a command prompt or terminal window.
    4. Navigate to the directory where your Python script is saved using the "cd" command.
    5. Type "python" followed by the name of your script and press enter. 
    6. a Python script will now execute.
-------------------------------------------------------------------------------------------------------------------------------------------------------

Q5. Given a list my_list = [1, 2, 3, 4, 5], write the code to slice the list and obtain the sub-list [2, 3].

Ans :
    my_list = [1, 2, 3, 4, 5]
    sub_list = my_list[1:3]
    print(sub_list)

    output:
            [2, 3]

-------------------------------------------------------------------------------------------------------------------------------------------------------

Q6. What is a complex number in mathematics, and how is it represented in Python?

Ans :
    Python helps to tackle and manipulate them. Complex numbers are created from two real numbers. 
    You can create it directly or you can use the complex function.
    It is written in the form of (x + yj) where x and y are real numbers and j is an imaginary number which is the square root of -1
-------------------------------------------------------------------------------------------------------------------------------------------------------

Q7. What is the correct way to declare a variable named age and assign the value 25 to it? 

ANS :
     age = 25

    This will create a variable named "age" and assign it the value of 25.
    
-------------------------------------------------------------------------------------------------------------------------------------------------------

Q8. Declare a variable named price and assign the value 9.99 to it. What data type does this variable belong to?

Ans :
    To declare a variable named price and assign the value 9.99 to it, you can write:


    price = 9.99

    This will create a variable named "price" and assign it the value of 9.99. 

    The data type of this variable is a floating-point number, or "float" for short.
    
-------------------------------------------------------------------------------------------------------------------------------------------------------

Q9. Create a variable named name and assign your full name to it as a string. How would you print the value of this variable?

Ans :
    name = "John Doe"  
        print(name)
    
-------------------------------------------------------------------------------------------------------------------------------------------------------

Q10. Given the string "Hello, World!", extract the substring "World".

Ans :
    s = "Hello, World!"
    substring = s[7:12]
    print(substring)

    output:
           World

-------------------------------------------------------------------------------------------------------------------------------------------------------

Q11. Create a variable named "is_student" and assign it a boolean value indicating whether you are currently a student or not.

Ans :
    is_student 
-------------------------------------------------------------------------------------------------------------------------------------------------------
